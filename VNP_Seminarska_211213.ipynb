# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df_ham = pd.read_csv('/content/drive/My Drive/Ham-Prices.csv')
df_meat = pd.read_csv('/content/drive/My Drive/Meat-Prices.csv')
df_fruit_2020 = pd.read_csv('/content/drive/My Drive/Fruit-Prices-2020.csv')
df_fruit_2021 = pd.read_csv('/content/drive/My Drive/Fruit-Prices-2021.csv')
df_fruit_2022 = pd.read_csv('/content/drive/My Drive/Fruit-Prices-2022.csv')
df_fruit_2023 = pd.read_csv('/content/drive/My Drive/Fruit-Prices-2023.csv')
df_vegetables_2020 = pd.read_csv('/content/drive/My Drive/Vegetable-Prices-2020.csv')
df_vegetables_2021 = pd.read_csv('/content/drive/My Drive/Vegetable-Prices-2021.csv')
df_vegetables_2022 = pd.read_csv('/content/drive/My Drive/Vegetable-Prices-2022.csv')
df_vegetables_2023 = pd.read_csv('/content/drive/My Drive/Vegetable-Prices-2023.csv')

# %%
df_vegetables_2023.head()
# Out:
#       Vegetable   Form  RetailPrice RetailPriceUnit     Yield  \
# 0  Acorn squash  Fresh         1.23       per pound    0.4586
# 1     Artichoke  Fresh         3.15       per pound  375.0000
# 2     Asparagus  Fresh         2.49       per pound    0.4938
# 3      Avocados  Fresh         1.79       per pound    0.7408
# 4   Black beans  Dried         1.39       per pound    2.4692
#
#    CupEquivalentSize CupEquivalentUnit  CupEquivalentPrice
# 0             0.4519            pounds              1.1961
# 1             0.3858            pounds              2.5415
# 2             0.3968            pounds              2.3731
# 3             0.3197            pounds              1.1538
# 4             0.3858            pounds              0.2383

# %%
df_vegetables_2020=df_vegetables_2020.drop(['Yield','CupEquivalentSize','CupEquivalentUnit','CupEquivalentPrice'],axis=1)
df_vegetables_2021=df_vegetables_2021.drop(['Yield','CupEquivalentSize','CupEquivalentUnit','CupEquivalentPrice'],axis=1)
df_vegetables_2022=df_vegetables_2022.drop(['Yield','CupEquivalentSize','CupEquivalentUnit','CupEquivalentPrice'],axis=1)
df_vegetables_2023=df_vegetables_2023.drop(['Yield','CupEquivalentSize','CupEquivalentUnit','CupEquivalentPrice'],axis=1)
df_fruit_2020=df_fruit_2020.drop(['Yield','CupEquivalentSize','CupEquivalentUnit','CupEquivalentPrice'],axis=1)
df_fruit_2021=df_fruit_2021.drop(['Yield','CupEquivalentSize','CupEquivalentUnit','CupEquivalentPrice'],axis=1)
df_fruit_2022=df_fruit_2022.drop(['Yield','CupEquivalentSize','CupEquivalentUnit','CupEquivalentPrice'],axis=1)
df_fruit_2023=df_fruit_2023.drop(['Yield','CupEquivalentSize','CupEquivalentUnit','CupEquivalentPrice'],axis=1)

# %%
df_vegetables_2020=df_vegetables_2020.rename(columns={'RetailPrice': 'Average Price from 2020'})
df_vegetables_2021=df_vegetables_2021.rename(columns={'RetailPrice': 'Average Price from 2021'})
df_vegetables_2022=df_vegetables_2022.rename(columns={'RetailPrice': 'Average Price from 2022'})
df_vegetables_2023=df_vegetables_2023.rename(columns={'RetailPrice': 'Average Price from 2023'})
df_fruit_2020=df_fruit_2020.rename(columns={'RetailPrice': 'Average Price from 2020'})
df_fruit_2021=df_fruit_2021.rename(columns={'RetailPrice': 'Average Price from 2021'})
df_fruit_2022=df_fruit_2022.rename(columns={'RetailPrice': 'Average Price from 2022'})
df_fruit_2023=df_fruit_2023.rename(columns={'RetailPrice': 'Average Price from 2023'})

# %%
df_vegetables_2020['Average Price from 2020']=df_vegetables_2020['Average Price from 2020']*2.2
df_vegetables_2020['RetailPriceUnit'] = df_vegetables_2020['RetailPriceUnit'].replace('per pound', 'per kilogram')
df_vegetables_2021['Average Price from 2021']=df_vegetables_2021['Average Price from 2021']*2.2
df_vegetables_2021['RetailPriceUnit'] = df_vegetables_2021['RetailPriceUnit'].replace('per pound', 'per kilogram')
df_vegetables_2022['Average Price from 2022']=df_vegetables_2022['Average Price from 2022']*2.2
df_vegetables_2022['RetailPriceUnit'] = df_vegetables_2022['RetailPriceUnit'].replace('per pound', 'per kilogram')
df_vegetables_2023['Average Price from 2023']=df_vegetables_2023['Average Price from 2023']*2.2
df_vegetables_2023['RetailPriceUnit'] = df_vegetables_2023['RetailPriceUnit'].replace('per pound', 'per kilogram')
df_fruit_2020['Average Price from 2020']=df_fruit_2020['Average Price from 2020']*2.2
df_fruit_2020['RetailPriceUnit'] = df_fruit_2020['RetailPriceUnit'].replace('per pound', 'per kilogram')
df_fruit_2021['Average Price from 2021']=df_fruit_2021['Average Price from 2021']*2.2
df_fruit_2021['RetailPriceUnit'] = df_fruit_2021['RetailPriceUnit'].replace('per pound', 'per kilogram')
df_fruit_2022['Average Price from 2022']=df_fruit_2022['Average Price from 2022']*2.2
df_fruit_2022['RetailPriceUnit'] = df_fruit_2022['RetailPriceUnit'].replace('per pound', 'per kilogram')
df_fruit_2023['Average Price from 2023']=df_fruit_2023['Average Price from 2023']*2.2
df_fruit_2023['RetailPriceUnit'] = df_fruit_2023['RetailPriceUnit'].replace('per pound', 'per kilogram')
df_fruit_2020['Average Price from 2020'] = df_fruit_2020['Average Price from 2020'].astype(float).round(2)
df_fruit_2021['Average Price from 2021'] = df_fruit_2021['Average Price from 2021'].astype(float).round(2)
df_fruit_2022['Average Price from 2022'] = df_fruit_2022['Average Price from 2022'].astype(float).round(2)
df_fruit_2023['Average Price from 2023'] = df_fruit_2023['Average Price from 2023'].astype(float).round(2)
df_vegetables_2020['Average Price from 2020'] = df_vegetables_2020['Average Price from 2020'].astype(float).round(2)
df_vegetables_2021['Average Price from 2021'] = df_vegetables_2021['Average Price from 2021'].astype(float).round(2)
df_vegetables_2022['Average Price from 2022'] = df_vegetables_2022['Average Price from 2022'].astype(float).round(2)
df_vegetables_2023['Average Price from 2023'] = df_vegetables_2023['Average Price from 2023'].astype(float).round(2)

# %%
df_vegetables_2023.head()
df_fruit_2022.head()
# Out:
#             Fruit    Form  Average Price from 2022 RetailPriceUnit
# 0          Apples   Fresh                     4.07    per kilogram
# 1        Apricots   Fresh                     7.94    per kilogram
# 2         Bananas   Fresh                     1.30    per kilogram
# 3  Berries, mixed  Frozen                     9.37    per kilogram
# 4    Blackberries   Fresh                    14.83    per kilogram

# %%
df_meat.head()
# Out:
#      Date Byproduct Gross farm value Net farm value Wholesale value  \
# 0  Jan-20      22,7            296,4          273,7           324,5
# 1  Feb-20      22,5            284,5            262           317,8
# 2  Mar-20      18,5            269,5            251           348,9
# 3  Apr-20      13,9            248,3          234,4             402
# 4  May-20       8,8              258          249,1           638,6
#
#    Retail value Total Farm-wholesale Wholesale-retail  \
# 0         605.9  3,32           50,8            281,4
# 1         604.5  3,42           55,7            286,7
# 2         604.6  3,54           97,9            255,7
# 3         644.4   4,1          167,5            242,4
# 4         758.5  5,09          389,5            119,9
#
#   All fresh beef retail value
# 0                       593,8
# 1                       593,5
# 2                       596,1
# 3                       622,2
# 4                       704,5

# %%
df_ham=df_ham.drop(['Byproduct','Gross farm value','Net farm value','Wholesale value','Total','Farm-wholesale','Wholesale-retail'],axis=1)
df_meat=df_meat.drop(['Byproduct','Gross farm value','Net farm value','Wholesale value','Total','Farm-wholesale','Wholesale-retail','All fresh beef retail value'],axis=1)

# %%
df_ham['Date'] = pd.to_datetime(df_ham['Date'], format='%b-%y')
df_ham['Year'] = df_ham['Date'].dt.year
df_ham['Retail value'] = df_ham['Retail value'].astype(float)
df_ham=df_ham.groupby('Year')['Retail value'].mean().reset_index().round(0)
df_meat['Date'] = pd.to_datetime(df_meat['Date'], format='%b-%y')
df_meat['Year'] = df_meat['Date'].dt.year
df_meat['Retail value'] = df_meat['Retail value'].astype(float)
df_meat=df_meat.groupby('Year')['Retail value'].mean().reset_index().round(0)

# %%
df_ham['Retail value']=df_ham['Retail value']/100
df_meat['Retail value']=df_meat['Retail value']/100
df_meat
# Out:
#    Year  Retail value
# 0  2020          6.54
# 1  2021          7.25
# 2  2022          7.59
# 3  2023          7.93

# %%
df_fruit_2020=df_fruit_2020.drop(['Form','RetailPriceUnit'],axis=1)
df_fruit_2021=df_fruit_2021.drop(['Form','RetailPriceUnit'],axis=1)
df_fruit_2022=df_fruit_2022.drop(['Form','RetailPriceUnit'],axis=1)
df_fruit_2023=df_fruit_2023.drop(['Form','RetailPriceUnit'],axis=1)
data_fruit_2020=pd.DataFrame(df_fruit_2020)
data_fruit_2021=pd.DataFrame(df_fruit_2021)
data_fruit_2022=pd.DataFrame(df_fruit_2022)
data_fruit_2023=pd.DataFrame(df_fruit_2023)
merged_fruits_df = pd.merge(data_fruit_2020, data_fruit_2021, on='Fruit', how='inner')
merged_fruits_df = pd.merge(merged_fruits_df, data_fruit_2022, on='Fruit', how='inner')
merged_fruits_df = pd.merge(merged_fruits_df, data_fruit_2023, on='Fruit', how='inner')
merged_fruits_df=merged_fruits_df.rename(columns={'Fruit': 'Food'})
merged_fruits_df
# Out:
#               Food  Average Price from 2020  Average Price from 2021  \
# 0           Apples                     3.28                     3.45
# 1         Apricots                     7.77                     7.96
# 2          Bananas                     1.28                     1.34
# 3   Berries, mixed                     9.92                     9.11
# 4     Blackberries                    11.04                     9.64
# 5      Blueberries                     9.48                     9.31
# 6       Cantaloupe                     1.32                     1.39
# 7         Cherries                     9.79                     7.52
# 8      Clementines                     7.48                     2.64
# 9      Cranberries                     5.50                     5.32
# 10           Dates                    11.26                     6.49
# 11            Figs                    13.20                     5.83
# 12      Grapefruit                     2.46                     2.97
# ...

# %%
df_vegetables_2020=df_vegetables_2020.drop(['Form','RetailPriceUnit'],axis=1)
df_vegetables_2021=df_vegetables_2021.drop(['Form','RetailPriceUnit'],axis=1)
df_vegetables_2022=df_vegetables_2022.drop(['Form','RetailPriceUnit'],axis=1)
df_vegetables_2023=df_vegetables_2023.drop(['Form','RetailPriceUnit'],axis=1)
data_vegetables_2020=pd.DataFrame(df_vegetables_2020)
data_vegetables_2021=pd.DataFrame(df_vegetables_2021)
data_vegetables_2022=pd.DataFrame(df_vegetables_2022)
data_vegetables_2023=pd.DataFrame(df_vegetables_2023)
merged_vegetables_df = pd.merge(data_vegetables_2020, data_vegetables_2021, on='Vegetable', how='inner')
merged_vegetables_df = pd.merge(merged_vegetables_df, data_vegetables_2022, on='Vegetable', how='inner')
merged_vegetables_df = pd.merge(merged_vegetables_df, data_vegetables_2023, on='Vegetable', how='inner')
merged_vegetables_df=merged_vegetables_df.rename(columns={'Vegetable': 'Food'})
merged_vegetables_df
# Out:
#                        Food  Average Price from 2020  Average Price from 2021  \
# 0              Acorn squash                     2.71                     3.30
# 1                 Artichoke                     6.05                     6.89
# 2                 Asparagus                     6.60                     7.72
# 3                  Avocados                     3.89                     4.44
# 4               Black beans                     3.43                     3.83
# 5             Blackeye peas                     4.38                     4.95
# 6                  Broccoli                     3.59                     3.96
# 7          Butternut squash                     3.34                     3.89
# 8            Cabbage, green                     1.30                     1.83
# 9              Cabbage, red                     1.80                     2.29
# 10      Cabbage, sauerkraut                     2.18                     2.68
# ...

# %%
merged_food_df = pd.merge(merged_vegetables_df, merged_fruits_df,how='outer')
merged_food_df = merged_food_df.sort_values(by=['Food'], ascending=True)
merged_food_df.head()
# Out:
#             Food  Average Price from 2020  Average Price from 2021  \
# 0   Acorn squash                     2.71                     3.30
# 26        Apples                     3.28                     3.45
# 27      Apricots                     7.77                     7.96
# 1      Artichoke                     6.05                     6.89
# 2      Asparagus                     6.60                     7.72
#
#     Average Price from 2022  Average Price from 2023
# 0                      2.66                     2.71
# 26                     4.07                     4.16
# 27                     7.94                     9.66
# 1                      5.43                     6.93
# 2                      6.49                     5.48

# %%
df_meat
# Out:
#    Year  Retail value
# 0  2020          6.54
# 1  2021          7.25
# 2  2022          7.59
# 3  2023          7.93

# %%
new_row = {'Food': 'Meat', 'Average Price from 2020': 6.54, 'Average Price from 2021': 7.25,'Average Price from 2022': 7.59,'Average Price from 2023': 7.93}
merged_food_df = pd.concat([merged_food_df, pd.DataFrame(new_row, index=[0])], ignore_index=True)

# %%
df_ham
# Out:
#    Year  Retail value
# 0  2020          4.03
# 1  2021          4.50
# 2  2022          4.90
# 3  2023          4.81

# %%
new_row = {'Food': 'Ham', 'Average Price from 2020': 4.03, 'Average Price from 2021': 4.50,'Average Price from 2022': 4.90,'Average Price from 2023': 4.81}
merged_food_df = pd.concat([merged_food_df, pd.DataFrame(new_row, index=[0])], ignore_index=True)
merged_food_df
# Out:
#                        Food  Average Price from 2020  Average Price from 2021  \
# 0              Acorn squash                     2.71                     3.30
# 1                    Apples                     3.28                     3.45
# 2                  Apricots                     7.77                     7.96
# 3                 Artichoke                     6.05                     6.89
# 4                 Asparagus                     6.60                     7.72
# 5                  Avocados                     3.89                     4.44
# 6                   Bananas                     1.28                     1.34
# 7            Berries, mixed                     9.92                     9.11
# 8               Black beans                     3.43                     3.83
# 9              Blackberries                    11.04                     9.64
# 10            Blackeye peas                     4.38                     4.95
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 18))
for i, food in enumerate(merged_food_df['Food']):
    plt.subplot(10, 6, i+1)
    plt.bar(['2020', '2021', '2022', '2023'], merged_food_df.iloc[i, 1:], color=['blue', 'green', 'orange', 'red'])
    plt.title(food)
    plt.ylim(0, 20)

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(4, 1, figsize=(12, 20), sharex=True, sharey=True)

for i, year in enumerate([2020, 2021, 2022, 2023]):
    axs[i].bar(merged_food_df['Food'], merged_food_df[f'Average Price from {year}'],color='green')
    axs[i].set_ylabel('Price')
    axs[i].set_title(f'Food Prices in {year}')
    axs[i].tick_params(axis='x', rotation=90)

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
merged_food_df.set_index('Food', inplace=True)

# Create the heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(merged_food_df, cmap='YlOrRd', annot=True, fmt='.2f', linewidths=.5)
plt.title('Average Prices of Foods (2020-2023)')
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
merged_food_df.isna().sum()
# Out:
# Average Price from 2020    0
# Average Price from 2021    0
# Average Price from 2022    0
# Average Price from 2023    0
# dtype: int64

# %%
merged_food_df['Average Price from 2024'] = merged_food_df[[
                                                      'Average Price from 2022', 'Average Price from 2023']].mean(axis=1).round(2)

merged_food_df.head()
# Out:
#               Average Price from 2020  Average Price from 2021  \
# Food
# Acorn squash                     2.71                     3.30
# Apples                           3.28                     3.45
# Apricots                         7.77                     7.96
# Artichoke                        6.05                     6.89
# Asparagus                        6.60                     7.72
#
#               Average Price from 2022  Average Price from 2023  \
# Food
# Acorn squash                     2.66                     2.71
# Apples                           4.07                     4.16
# Apricots                         7.94                     9.66
# Artichoke                        5.43                     6.93
# Asparagus                        6.49                     5.48
#
#               Average Price from 2024
# Food
# Acorn squash                     2.68
# Apples                           4.12
# Apricots                         8.80
# ...

# %%
merged_food_df_copy=merged_food_df

# %%
X,Y=merged_food_df_copy.drop('Average Price from 2024',axis=1),merged_food_df_copy['Average Price from 2024']
X_train=X.iloc[:int(len(merged_food_df_copy)*0.8),:]
X_test=X.iloc[int(len(merged_food_df_copy)*0.8):,:]
Y_train=Y[:int(len(merged_food_df_copy)*0.8)]
Y_test=Y[int(len(merged_food_df_copy)*0.8):]

# %% [markdown]
# **Bagging**

# %%
from sklearn.ensemble import RandomForestRegressor
forest=RandomForestRegressor()
forest.fit(X_train,Y_train)
# Out:
# RandomForestRegressor()

# %%
Y_pred = forest.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score
print(mean_squared_error(Y_test,Y_pred))
print(r2_score(Y_test,Y_pred))
# Out:
# 0.6180394141666646
# 0.9484946648107287

# %% [markdown]
# **Boosting**

# %%
from xgboost import XGBRegressor
model = XGBRegressor()
model.fit(X_train,Y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
Y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score
print(mean_squared_error(Y_test,Y_pred))
print(r2_score(Y_test,Y_pred))
# Out:
# 0.8311568557708017
# 0.9307341708796071

# %% [markdown]
# **Random Forest**

# %%
from sklearn.model_selection import GridSearchCV
X_train=X.iloc[:int(len(merged_food_df_copy)*0.9),:]
X_test=X.iloc[int(len(merged_food_df_copy)*0.9):,:]
Y_train=Y[:int(len(merged_food_df_copy)*0.9)]
Y_test=Y[int(len(merged_food_df_copy)*0.9):]

# %%
max_depth_list = [9, 11,13,15]
parameters= {
               "max_depth": max_depth_list}
from sklearn.model_selection import TimeSeriesSplit
model=RandomForestRegressor()
model_cv=GridSearchCV(model,parameters,cv=TimeSeriesSplit(n_splits=5))
model_cv.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=5, test_size=None),
#              estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [9, 11, 13, 15]})

# %%
print(model_cv.best_params_)
# Out:
# {'max_depth': 13}

# %%
Y_pred=model_cv.predict(X_test)
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
print(mean_absolute_error(Y_test,Y_pred))
print(r2_score(Y_test,Y_pred))
# Out:
# 0.9529499999999994
# 0.9253351034903341

# %% [markdown]
# **LSTM**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, shuffle=False)

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
Y_train = scaler.fit_transform(Y_train.values.reshape(-1, 1))

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

model = Sequential()
model.add(LSTM(100,  activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
model.add(LSTM(50,  activation='relu'))
model.add(Dense(1, activation='linear'))

# %%
import keras
model.compile(loss=keras.losses.MeanSquaredError() , optimizer=keras.optimizers.Adam(), metrics=[keras.metrics.MeanSquaredError(), keras.metrics.MeanAbsoluteError() ])

# %%
history = model.fit(X_train, Y_train, batch_size=16, validation_split=0.2, epochs=20, shuffle=False)
# Out:
# Epoch 1/20
# 3/3 [==============================] - 4s 751ms/step - loss: 0.1382 - mean_squared_error: 0.1382 - mean_absolute_error: 0.2741 - val_loss: 0.0377 - val_mean_squared_error: 0.0377 - val_mean_absolute_error: 0.1735
# Epoch 2/20
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1292 - mean_squared_error: 0.1292 - mean_absolute_error: 0.2609 - val_loss: 0.0327 - val_mean_squared_error: 0.0327 - val_mean_absolute_error: 0.1594
# Epoch 3/20
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1202 - mean_squared_error: 0.1202 - mean_absolute_error: 0.2474 - val_loss: 0.0278 - val_mean_squared_error: 0.0278 - val_mean_absolute_error: 0.1442
# Epoch 4/20
# 3/3 [==============================] - 0s 46ms/step - loss: 0.1106 - mean_squared_error: 0.1106 - mean_absolute_error: 0.2330 - val_loss: 0.0230 - val_mean_squared_error: 0.0230 - val_mean_absolute_error: 0.1272
# Epoch 5/20
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend()
plt.show()

# %%
preds = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 308ms/step

# %%
preds = scaler.inverse_transform(preds)

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
mean_squared_error(preds, Y_test), mean_absolute_error(preds, Y_test), r2_score(preds, Y_test)
# Out:
# (1.3369339544169376, 0.9764932656288146, 0.8397346708777162)

# %%
plt.figure(figsize=(20, 10))
plt.plot(Y_test.values, label='actual')
plt.plot(preds, label='predicted')
plt.legend()
plt.show()

# %% [markdown]
# **Linear Regression**

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
X = merged_food_df_copy[['Average Price from 2020', 'Average Price from 2021', 'Average Price from 2022', 'Average Price from 2023']]
y = merged_food_df_copy['Average Price from 2024']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

lr_model = LinearRegression()
lr_model.fit(X_train, y_train)

y_pred = lr_model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)


print(f'Mean Squared Error (MSE): {mse}')
print(f'R-squared (R2): {r2}')

plt.scatter(y_test, y_pred, color='blue')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linewidth=2)
plt.xlabel('Actual Average Price 2024')
plt.ylabel('Predicted Average Price 2024')
plt.title('Actual vs Predicted Average Price 2024')
plt.show()
# Out:
# Mean Squared Error (MSE): 1.184537788984989e-05
# R-squared (R2): 0.9999990783550365
